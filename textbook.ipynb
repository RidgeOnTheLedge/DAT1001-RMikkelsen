# %%
# Read two books, fast!
import 
huck_finn_url = 'https://www.inferentialthinking.com/data/huck_finn.txt'
huck_finn_text = read_url(huck_finn_url)
huck_finn_chapters = huck_finn_text.split('CHAPTER ')[44:]

little_women_url = 'https://www.inferentialthinking.com/data/little_women.txt'
little_women_text = read_url(little_women_url)
little_women_chapters = little_women_text.split('CHAPTER ')[1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Read two books, fast!
#       2
#       3 huck_finn_url = 'https://www.inferentialthinking.com/data/huck_finn.txt'
# ----> 4 huck_finn_text = read_url(huck_finn_url)
#       5 huck_finn_chapters = huck_finn_text.split('CHAPTER ')[44:]
#       6
#       7 little_women_url = 'https://www.inferentialthinking.com/data/little_women.txt'
#
# NameError: name 'read_url' is not defined
