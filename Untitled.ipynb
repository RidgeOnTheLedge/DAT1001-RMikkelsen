# %%
import numpy as np
np
# Out:
# <module 'numpy' from 'C:\\Users\\rlmik\\AppData\\Roaming\\Python\\Python314\\site-packages\\numpy\\__init__.py'>

# %%
quizs = [1, 6, 7, 2, 67, 32, 2, 5,374, 3, 2]

test = [c for c in quizs]

# %%
test
# Out:
# [1, 6, 7, 2, 67, 32, 2, 5, 374, 3, 2]

# %%
# slicing 
a = np.arange(15).reshape(3, 5)

# %%
a[-1: 1]
# Out:
# array([], shape=(0, 5), dtype=int64)

# %%
b = a[a[0:13] == 1]

# %%
b
# Out:
# array([1])

# %%
a = [c for c in range(10)]
